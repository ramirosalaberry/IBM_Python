# %% [markdown]
# # Batalla de los barrios. Toronto.

# %% [markdown]
# ## TOC:
# * [Obtener datos de barrios y coordenadas](#first-bullet)
# * [Obtener datos demográficos de residentes sudamericanos](#second-bullet)
# * [Obtener datos de negocios con Foursquare](#tres-bullet)

# %% [markdown]
# ## Obtener datos de barrios y coordenadas <a class="anchor" id="first-bullet"></a>

# %%
#Importo las librerías paquetes que necesito.
import re
import numpy as np # librería para manejar datos vectorizados

import pandas as pd # librería para análisis de datos
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # librería para manejar archivos JSON 

#!conda install -c conda-forge geopy --yes 
# !pip install geopy
from geopy.geocoders import Nominatim # convertir una dirección en valores de latitud y longitud

import requests # librería para manejar solicitudes
from pandas.io.json import json_normalize # librería para convertir un archivo json en un dataframe pandas

# Matplotlib y módulos asociados para graficar
import matplotlib.cm as cm
import matplotlib.colors as colors

# importar k-means desde la fase de agrupación
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
! pip install folium==0.5.0
import folium # librería para graficar mapas 

# se carga beautiful soup para el trabajo con HTML
#!conda install -c conda-forge beautifulsoup4 --yes
! pip install beautifulsoup4
from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# ...
# Libraries imported.

# %% [markdown]
# Cargo las tablas desde las paginas HTML que previamente guardé

# %%
with open('List of postal codes of Canada_ M - Wikipedia.html', encoding="utf8") as fp:
    soup = BeautifulSoup(fp, "html.parser")
table = soup.find_all('table')
df = pd.read_html(str(table))[0]
df
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %%
with open('Postal Code of Toronto Ontario - Canada Postal Code List - ZIPCODESONLINE.html', encoding="utf8") as fp2:
    soup = BeautifulSoup(fp2, "html.parser")
table2 = soup.find_all('table')
df2 = pd.read_html(str(table2))[1]
df2=df2.drop(columns=[0], axis=0)
df2= df2.drop(1)
col2 = ['Neighborhood','PostalCode', 'Borough']
df2.columns=col2
df2= df2.drop(0)
df2 = df2.reset_index(drop=True)
df2.sort_values(by='Neighborhood')
df2.head()
# Out:
#       Neighborhood PostalCode           Borough
# 0         Adelaide        M5H  Downtown Toronto
# 1  Agincourt North        M1V       Scarborough
# 2        Agincourt        M1S       Scarborough
# 3   Albion Gardens        M9V         Etobicoke
# 4        Alderwood        M8W         Etobicoke

# %%
with open('Neighbourhood Profiles – City of Toronto.html', encoding="utf8") as fp3:
    soup = BeautifulSoup(fp3, "html.parser")
table3 = soup.find_all('table')
df3 = pd.read_html(str(table3))[1]
col3 = ['Hood #','Neighborhood']
df3.columns=col3
df3 = df3.reset_index(drop=True)
df3.sort_values(by='Neighborhood')
df3.head()
# Out:
#    Hood #                       Neighborhood
# 0       1             West Humber-Clairville
# 1       2  Mount Olive-Silverstone-Jamestown
# 2       3       Thistletown-Beaumond Heights
# 3       4                    Rexdale-Kipling
# 4       5                   Elms-Old Rexdale

# %% [markdown]
# Busco las coordenadas de los 140 barrios a través del servicio de Geolocator. Se obtienen 108 de 140 registros.

# %%
barrio=[]
lat=[]
long=[]
barrio_num=[]
for i in range(len(df3)):
    try:
        address  = df3.loc[i,'Neighborhood']+','+'Toronto'
        geolocator = Nominatim(user_agent="Tor_explorer")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        barrio.append(df3.loc[i,'Neighborhood'])
        lat.append(latitude)
        long.append(longitude)
        barrio_num.append(df3.loc[i,'Hood #'])
    except:
        barrio_num.append(df3.loc[i,'Hood #'])
        barrio.append(df3.loc[i,'Neighborhood'])
        lat.append(None)
        long.append(None)
col32=['Hood #','Neighborhood', 'Latitude', 'Longitude']
df32=pd.DataFrame(columns=col32)
df32['Hood #']=barrio_num
df32['Neighborhood']=barrio
df32['Latitude']=lat
df32['Longitude']=long
df32.head()
# Out:
#    Hood #                       Neighborhood   Latitude  Longitude
# 0       1             West Humber-Clairville  43.722563 -79.597039
# 1       2  Mount Olive-Silverstone-Jamestown        NaN        NaN
# 2       3       Thistletown-Beaumond Heights        NaN        NaN
# 3       4                    Rexdale-Kipling  43.722114 -79.572292
# 4       5                   Elms-Old Rexdale  43.721770 -79.552173

# %% [markdown]
# Paso los registros nulos a otro data frame para analizarlos separadamente.

# %%
df32nan=df32[df32.isnull().any(axis=1)]

# %% [markdown]
# Hay 32 valores Nan correspondientes a barrios de los cuales no se encontraron las coordenadas. Formo otro Data Frame con los barrios que faltan completar y los estudio aparte.

# %% [markdown]
# Viendo los vecindarios que quedaron como NaN, la gran mayoría son de dos palabras separadas por -. Luego hay una de una sola palabra ('Humbermede' antiguamente 'Emery'), dos que tienen parentesis ('Taylor-Massey (formerly Crescent Town)' y 'Mimico (includes Humber Bay Shores)' y otros que esta separado por espacios ('Lambton Baby Point', 'Woodbine Corridor''y 'Parkwoods Donalda')). Un caso particular es 'Thistletown-Beaumond Heights', el cual es mas conocido solo como 'Thistletown' y por lo tanto se cambia a ese nombre para poder obtener sus coordenadas. Separo los nombres de los barrios para usar su segunda denominación y poder encontrar las coordenadas.

# %%
barrio2=[]
for f in range(len(df32nan)):
    n=df32nan.iloc[f,1]
    nsplit_aux=re.split('[(]',n)
    n2=nsplit_aux[0]
    nsplit=re.split('-',n2)
    if len(nsplit)>1:
        barrio2.append(nsplit[1])
    else:
        barrio2.append(nsplit[0])
df32nan['Neighborhood2']=barrio2
df32nan
# Out:
# C:\Users\Ramiro Salaberry\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#      Hood #                            Neighborhood  Latitude  Longitude  \
# 1         2       Mount Olive-Silverstone-Jamestown       NaN        NaN
# 2         3            Thistletown-Beaumond Heights       NaN        NaN
# 5         6           Kingsview Village-The Westway       NaN        NaN
# 6         7        Willowridge-Martingrove-Richview       NaN        NaN
# 9        10                      Princess-Rosethorn       NaN        NaN
# 10       11          Eringate-Centennial-West Deane       NaN        NaN
# ...

# %%
old=['Humbermede', 'Lambton Baby Point', 'Woodbine Corridor','Parkwoods Donalda','Beaumond Heights']
new=['Emery',  'Baby Point', 'Corridor','Donalda','Thistletown']
df32nan['Neighborhood2']=df32nan['Neighborhood2'].replace(old,new)
df32nan = df32nan.reset_index(drop=True)
df32nan.head()
# Out:
# C:\Users\Ramiro Salaberry\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    Hood #                       Neighborhood  Latitude  Longitude  \
# 0       2  Mount Olive-Silverstone-Jamestown       NaN        NaN
# 1       3       Thistletown-Beaumond Heights       NaN        NaN
# 2       6      Kingsview Village-The Westway       NaN        NaN
# 3       7   Willowridge-Martingrove-Richview       NaN        NaN
# 4      10                 Princess-Rosethorn       NaN        NaN
#
#   Neighborhood2
# 0   Silverstone
# 1   Thistletown
# 2   The Westway
# 3   Martingrove
# 4     Rosethorn

# %% [markdown]
# Intento de nuevo con los barrios que faltan cambiando a la segunda nominación del barrio, despues del '-' y corrigiendo los barrios con parentesis'()'. El resultado es existoso, lograndose la totalidad de las coordenadas. Ahora hay que unir este segundo data frame al primero. Para eso eliminamos los Nan del primero y hacemos una concatenación con los del segundo data frame. Previamente elimino tambien la columna 'Neighborhood2' usada para hallar las coordenadas de los barrios con Nan iniciales.

# %%
barrio32=[]
lat32=[]
long32=[]
barrio32_num=[]
for i in range(len(df32nan)):
    try:
        address  = df32nan.loc[i,'Neighborhood2']+','+'Toronto'
        geolocator = Nominatim(user_agent="Tor_explorer")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        barrio32_num.append(df32nan.loc[i,'Hood #'])
        barrio32.append(df32nan.loc[i,'Neighborhood2'])
        lat32.append(latitude)
        long32.append(longitude)
    except:
        barrio32_num.append(df32nan.loc[i,'Hood #'])
        barrio32.append(df32nan.loc[i,'Neighborhood2'])
        lat32.append(None)
        long32.append(None)
df32nan['Hood #']=barrio32_num
df32nan['Neighborhood2']=barrio32
df32nan['Latitude']=lat32
df32nan['Longitude']=long32
df32nan.head()
# Out:
#    Hood #                       Neighborhood   Latitude  Longitude  \
# 0       2  Mount Olive-Silverstone-Jamestown  43.749751 -79.599116
# 1       3       Thistletown-Beaumond Heights  43.737266 -79.565317
# 2       6      Kingsview Village-The Westway  43.683437 -79.566514
# 3       7   Willowridge-Martingrove-Richview  43.673954 -79.560480
# 4      10                 Princess-Rosethorn  43.658474 -79.539097
#
#   Neighborhood2
# 0   Silverstone
# 1   Thistletown
# 2   The Westway
# 3   Martingrove
# 4     Rosethorn

# %% [markdown]
# Elimino la columna de barrios 2 usada para hallar las coordenadas con la segunda denominación de cada barrio.

# %%
df32nan=df32nan.drop(['Neighborhood2'], axis=1)

# %%
df32nan.head()
# Out:
#    Hood #                       Neighborhood   Latitude  Longitude
# 0       2  Mount Olive-Silverstone-Jamestown  43.749751 -79.599116
# 1       3       Thistletown-Beaumond Heights  43.737266 -79.565317
# 2       6      Kingsview Village-The Westway  43.683437 -79.566514
# 3       7   Willowridge-Martingrove-Richview  43.673954 -79.560480
# 4      10                 Princess-Rosethorn  43.658474 -79.539097

# %% [markdown]
# Elimino los registros con Nan para poder hacer el concatenamiento entre los dos datas frames

# %%
df32=df32.dropna()
df32.head()
# Out:
#    Hood #              Neighborhood   Latitude  Longitude
# 0       1    West Humber-Clairville  43.722563 -79.597039
# 3       4           Rexdale-Kipling  43.722114 -79.572292
# 4       5          Elms-Old Rexdale  43.721770 -79.552173
# 7       8  Humber Heights-Westmount  43.697777 -79.521222
# 8       9  Edenbridge-Humber Valley  43.670015 -79.521948

# %% [markdown]
# Entre los dos datas frames suman los 140 barrio originales del portal de datos de la ciudad de Toronto con sus coordenadas en cada barrio.

# %%
df32.shape, df32nan.shape
# Out:
# ((108, 4), (32, 4))

# %%
df32 = pd.concat([df32, df32nan])

# %% [markdown]
# Hago la concatenación, reseto el indice y finalmente obtengo el data frame con los 140 barrios y sus coordenadas.

# %%
df32 = df32.reset_index(drop=True)
print(df32.shape)
df32.sort_values(by='Hood #').head()
# Out:
# (140, 4)
#      Hood #                       Neighborhood   Latitude  Longitude
# 0         1             West Humber-Clairville  43.722563 -79.597039
# 108       2  Mount Olive-Silverstone-Jamestown  43.749751 -79.599116
# 109       3       Thistletown-Beaumond Heights  43.737266 -79.565317
# 1         4                    Rexdale-Kipling  43.722114 -79.572292
# 2         5                   Elms-Old Rexdale  43.721770 -79.552173

# %%
df32.to_csv('datos_barrios_coord.csv')

# %% [markdown]
# Para ver el resultado, creamos un mapa con todos los Barrios de Toronto.

# %%
address = 'Toronto, TOR'
geolocator = Nominatim(user_agent="Tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.7370584, -79.2442535.

# %%
# crear un mapa de Toronto utilizando los valores de latitud y longitud
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# añadir marcadores al mapa
for lat, lng, neighborhood, hood in zip(df32['Latitude'], df32['Longitude'], df32['Neighborhood'],df32['Hood #'] ):
    label = '{}, hood n° {}'.format(neighborhood, hood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        #popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    folium.Circle(
        radius=300,
        popup=label,
        location=[lat,lng],
        color='#3186cc',
        fill=True,
        fill_color='#3186cc'
    ).add_to(map_toronto) 
    
    
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ## Obtener datos demográficos de residentes sudamericanos <a class="anchor" id="second-bullet"></a>

# %%
df_demo=pd.read_csv('neighbourhood-profiles-2016-csv.csv',decimal=",")

# %%
df_demo.head()
# Out:
#    _id                   Category                      Topic  \
# 0    1  Neighbourhood Information  Neighbourhood Information
# 1    2  Neighbourhood Information  Neighbourhood Information
# 2    3                 Population   Population and dwellings
# 3    4                 Population   Population and dwellings
# 4    5                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# ...

# %%
for i in range(len(df_demo)):
    cad=df_demo.loc[i,'Characteristic']
    df_demo.loc[i,'Characteristic']=cad.strip()

# %%
valores_a_buscar=['Neighbourhood Number',
                  'Total income: Average amount ($)',
                  'Brazil', 
                  'Brazilian', 
                  'Argentinian',
                  'Chilean',
                  'Paraguayan',
                  'Uruguayan']
[True if item in df_demo.values else False for item in valores_a_buscar]
# Out:
# [True, True, True, True, True, True, True, True]

# %%
df_demo2 = df_demo[df_demo.Characteristic.isin(valores_a_buscar)]
df_demo2=df_demo2.drop(['_id', 'Category', 'Topic','Data Source','City of Toronto'], axis=1)
df_demo2 = df_demo2.reset_index(drop=True)
columns=df_demo2.columns
for i in range(1,len(columns),1):
    df_demo2.iloc[8,i] = df_demo2.iloc[8,i].replace(",", "")
    val=df_demo2.iloc[8,i]
    df_demo2.iloc[8,i] = pd.to_numeric(val, errors='coerce')
    df_demo2.iloc[1,i] = pd.to_numeric(df_demo2.iloc[1,i], errors='coerce')
    df_demo2.iloc[2,i] = pd.to_numeric(df_demo2.iloc[2,i], errors='coerce')
df_demo2.iloc[1,:]=df_demo2.iloc[1,:]+df_demo2.iloc[2,:]
df_demo2=df_demo2.drop(2, axis=0)
df_demo2 = df_demo2.reset_index(drop=True)
for f in range(len(df_demo2.index)):
    for c in range(1,len(columns),1):
        df_demo.iloc[f,c]=pd.to_numeric(df_demo.iloc[f,c], downcast='integer',errors='coerce')
df_demo2
# Out:
#                      Characteristic Agincourt North  \
# 0              Neighbourhood Number             129
# 1                      BrazilBrazil              10
# 2                       Argentinian               0
# 3                         Brazilian               0
# 4                           Chilean              20
# 5                        Paraguayan               0
# 6                         Uruguayan               0
# 7  Total income: Average amount ($)           30414
#
#   Agincourt South-Malvern West Alderwood   Annex Banbury-Don Mills  \
# 0                          128        20      95                42
# 1                           30        45      80                40
# 2                            0        20      65                45
# 3                           15        30      45                30
# 4                            0        25      50                20
# 5                            0         0       0                 0
# ...

# %%
df_demo22=df_demo2.transpose()
df_demo22 = df_demo22.rename_axis('index').reset_index()
fila0=df_demo22.loc[0,:]
df_demo22.columns=fila0
df_demo22=df_demo22.drop(0,axis=0)
df_demo22 = df_demo22.reset_index(drop=True)
df_demo22 = df_demo22.rename(columns={'Characteristic':'Neighborhood',
                                   'Neighbourhood Number':'Hood #',
                                     'BrazilBrazil':'Brazil'})
df_demo22.head()
# Out:
# 0                  Neighborhood Hood # Brazil Argentinian Brazilian Chilean  \
# 0               Agincourt North    129     10           0         0      20
# 1  Agincourt South-Malvern West    128     30           0        15       0
# 2                     Alderwood     20     45          20        30      25
# 3                         Annex     95     80          65        45      50
# 4             Banbury-Don Mills     42     40          45        30      20
#
# 0 Paraguayan Uruguayan Total income: Average amount ($)
# 0          0         0                            30414
# 1          0         0                            31825
# 2          0         0                            47709
# 3          0        10                           112766
# 4          0         0                            67757

# %%
filas=df_demo22.index
colu=df_demo22.columns
len(filas), len(colu)
for f in range(len(filas)):
    for c in range(1, len(colu)-2,1):
        df_demo22.iloc[f,c]=pd.to_numeric(df_demo22.iloc[f,c], downcast='integer',errors='coerce')
df_demo22['Total migrantes sudamericanos']=df_demo22.iloc[:,-7:-2].sum(axis=1)
df_demo22 = df_demo22.reset_index(drop=True)

# %%
df_demo22.head()
# Out:
# 0                  Neighborhood Hood # Brazil Argentinian Brazilian Chilean  \
# 0               Agincourt North    129     10           0         0      20
# 1  Agincourt South-Malvern West    128     30           0        15       0
# 2                     Alderwood     20     45          20        30      25
# 3                         Annex     95     80          65        45      50
# 4             Banbury-Don Mills     42     40          45        30      20
#
# 0 Paraguayan Uruguayan Total income: Average amount ($)  \
# 0          0         0                            30414
# 1          0         0                            31825
# 2          0         0                            47709
# 3          0        10                           112766
# 4          0         0                            67757
#
# 0  Total migrantes sudamericanos
# 0                           30.0
# 1                           45.0
# 2                          120.0
# ...

# %%
df_demo22.to_csv('dato_demografico.csv')

# %%
df_demo=pd.read_csv('dato_demografico.csv',index_col=0)
df_coor=pd.read_csv('datos_barrios_coord.csv',index_col=0)

# %%
df_demo.sort_values(by='Total migrantes sudamericanos', ascending=False).head()
# Out:
#                             Neighborhood  Hood #  Brazil  Argentinian  \
# 32   Dovercourt-Wallace Emerson-Junction      93     385           75
# 33                  Downsview-Roding-CFB      26      85          245
# 102                    Rockcliffe-Smythe     111     320           75
# 122    Waterfront Communities-The Island      77     300           95
# 58            Islington-City Centre West      14     230          125
#
#      Brazilian  Chilean  Paraguayan  Uruguayan  \
# 32         405      120           0         10
# 33         135      310          30         65
# 102        300       60           0         10
# 122        240      110           0         20
# 58         230      105          45         10
#
#      Total income: Average amount ($)  Total migrantes sudamericanos
# 32                              39740                          985.0
# 33                              34168                          805.0
# ...

# %%
df_demo=df_demo.drop(['Brazil', 'Argentinian', 'Brazilian', 'Chilean', 'Paraguayan', 'Uruguayan'],axis=1)

# %%
df_demo['Total Normalizado']=df_demo['Total migrantes sudamericanos']/df_demo['Total migrantes sudamericanos'].max()
df_demo['Total Income Norm']=df_demo['Total income: Average amount ($)']/df_demo['Total income: Average amount ($)'].max()
df_demo.head()
# Out:
#                    Neighborhood  Hood #  Total income: Average amount ($)  \
# 0               Agincourt North     129                             30414
# 1  Agincourt South-Malvern West     128                             31825
# 2                     Alderwood      20                             47709
# 3                         Annex      95                            112766
# 4             Banbury-Don Mills      42                             67757
#
#    Total migrantes sudamericanos  Total Normalizado  Total Income Norm
# 0                           30.0           0.030457           0.098744
# 1                           45.0           0.045685           0.103325
# 2                          120.0           0.121827           0.154894
# 3                          240.0           0.243655           0.366111
# 4                          135.0           0.137056           0.219983

# %%
df_coor.head()
# Out:
#    Hood #              Neighborhood   Latitude  Longitude
# 0       1    West Humber-Clairville  43.722563 -79.597039
# 1       4           Rexdale-Kipling  43.722114 -79.572292
# 2       5          Elms-Old Rexdale  43.721770 -79.552173
# 3       8  Humber Heights-Westmount  43.697777 -79.521222
# 4       9  Edenbridge-Humber Valley  43.670015 -79.521948

# %%
df_demo=df_demo.merge(df_coor,how='inner',on=['Hood #'])
df_demo.head()
# Out:
#                  Neighborhood_x  Hood #  Total income: Average amount ($)  \
# 0               Agincourt North     129                             30414
# 1  Agincourt South-Malvern West     128                             31825
# 2                     Alderwood      20                             47709
# 3                         Annex      95                            112766
# 4             Banbury-Don Mills      42                             67757
#
#    Total migrantes sudamericanos  Total Normalizado  Total Income Norm  \
# 0                           30.0           0.030457           0.098744
# 1                           45.0           0.045685           0.103325
# 2                          120.0           0.121827           0.154894
# 3                          240.0           0.243655           0.366111
# 4                          135.0           0.137056           0.219983
#
#                  Neighborhood_y   Latitude  Longitude
# ...

# %%
df_demo.shape
# Out:
# (140, 9)

# %%
for f in range(len(df_demo)):
    if df_demo.loc[f,'Neighborhood_x']!=df_demo.loc[f,'Neighborhood_y']:
        print(f, '\n', 'Neighborhood_x =', df_demo.loc[f,'Neighborhood_x'] ,'><','Neighborhood_y =' ,df_demo.loc[f,'Neighborhood_y'] )
# Out:
# 29
#  Neighborhood_x = Danforth East York >< Neighborhood_y = Danforth - East York
# 70
#  Neighborhood_x = Leaside-Bennington >< Neighborhood_y = Leaside Bennington
# 95
#  Neighborhood_x = Parkwoods-Donalda >< Neighborhood_y = Parkwoods Donalda
# 111
#  Neighborhood_x = St.Andrew-Windfields >< Neighborhood_y = St. Andrew-Windfields
# 115
#  Neighborhood_x = Taylor-Massey >< Neighborhood_y = Taylor-Massey (formerly Crescent Town)
# 128
#  Neighborhood_x = Wexford/Maryvale >< Neighborhood_y = Wexford-Maryvale

# %%
address = 'Toronto, TOR'
geolocator = Nominatim(user_agent="Tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.7370584, -79.2442535.

# %%
# crear un mapa de Toronto utilizando los valores de latitud y longitud
map_toronto2 = folium.Map(location=[latitude, longitude], zoom_start=10)
# añadir marcadores al mapa
for lat, lng, neighborhood, hood, radio, pop, radioincome, income in zip(df_demo['Latitude'], df_demo['Longitude'], 
                                               df_demo['Neighborhood_x'],df_demo['Hood #'],
                                                df_demo['Total Normalizado'],df_demo['Total migrantes sudamericanos'],
                                                df_demo['Total Income Norm'],df_demo['Total income: Average amount ($)']):
    label1 = '{}, hood n° {}, pop. {} '.format(neighborhood, hood, pop)
    label1 = folium.Popup(label1, parse_html=True)
    label2 = '{}, hood n° {}, Income. {} '.format(neighborhood, hood, income)
    label2 = folium.Popup(label2, parse_html=True)

    folium.CircleMarker(
        [lat, lng],
        radius=1,
        #popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto2)
    folium.Circle(
        radius=radio*500,
        popup=label1,
        location=[lat,lng],
        color='red',
        fill=True,
        fill_color='red'
    ).add_to(map_toronto2) 
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        #popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto2)
    folium.Circle(
        radius=radioincome*500,
        popup=label2,
        location=[lat,lng],
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_to(map_toronto2)

# %%
map_toronto2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
df_demo2=df_demo
toronto_grouped_clustering = df_demo2.drop(['Neighborhood_x','Neighborhood_y', 'Hood #', 
                                            'Total Normalizado','Total Income Norm'], 1)

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist

kmeans_kwargs = {"init": "k-means++","n_init": 10,"max_iter": 300,"random_state": 0,}
# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(toronto_grouped_clustering)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
# establecer el número de agrupaciones
df_demo2=df_demo
kclusters = 3

toronto_grouped_clustering = df_demo2.drop(['Neighborhood_x','Neighborhood_y', 'Hood #', 
                                            'Total Normalizado','Total Income Norm'], 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 1, 1, 0, 0, 0, 0, 1])

# %%
df_demo2.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
df_demo2.head()
# Out:
#    Cluster Labels                Neighborhood_x  Hood #  \
# 0               0               Agincourt North     129
# 1               0  Agincourt South-Malvern West     128
# 2               0                     Alderwood      20
# 3               1                         Annex      95
# 4               1             Banbury-Don Mills      42
#
#    Total income: Average amount ($)  Total migrantes sudamericanos  \
# 0                             30414                           30.0
# 1                             31825                           45.0
# 2                             47709                          120.0
# 3                            112766                          240.0
# 4                             67757                          135.0
#
#    Total Normalizado  Total Income Norm                Neighborhood_y  \
# 0           0.030457           0.098744               Agincourt North
# 1           0.045685           0.103325  Agincourt South-Malvern West
# ...

# %%
address = 'Toronto, TOR'
geolocator = Nominatim(user_agent="Tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.7370584, -79.2442535.

# %%
# crear mapa
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster, radio in zip(df_demo2['Latitude'], df_demo2['Longitude'],
                                         df_demo2['Neighborhood_x'], df_demo2['Cluster Labels'], df_demo2['Total Normalizado']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10*radio,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
for i in range(0,3,1):
    print('Cluster {}, ingreso medio {}, población sudamericana media {}, cantidad barrios {} '.format(
    df_demo2.loc[df_demo2['Cluster Labels'] == i].mean()[0], df_demo2.loc[df_demo2['Cluster Labels'] == i].mean()[2],
    df_demo2.loc[df_demo2['Cluster Labels'] == i].mean()[3], df_demo2.loc[df_demo2['Cluster Labels'] == i].count()[1]))
# Out:
# Cluster 0.0, ingreso medio 41146.238938053095, población sudamericana media 206.32743362831857, cantidad barrios 113
# Cluster 1.0, ingreso medio 92299.09090909091, población sudamericana media 165.22727272727272, cantidad barrios 22
# Cluster 2.0, ingreso medio 210936.8, población sudamericana media 113.0, cantidad barrios 5

# %% [markdown]
# ## Obtener datos de negocios con Foursquare <a class="anchor" id="tres-bullet"></a>

# %%
CLIENT_ID = 'TKDEL1UDPMTSHP2J0DTMAMEJAXWSZOT1EHMVGYQHE5Z1XYXG' # su ID de Foursquare
CLIENT_SECRET = 'BZSEZJINU52JACXRQMH5A0PZBZMMV2HFF4XP1F2G0TKOJ32M' # Secreto de Foursquare
VERSION = '20210709' # versión de la API de Foursquare
LIMIT = 100 # Un valor límite para la API de Foursquare

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TKDEL1UDPMTSHP2J0DTMAMEJAXWSZOT1EHMVGYQHE5Z1XYXG
# CLIENT_SECRET:BZSEZJINU52JACXRQMH5A0PZBZMMV2HFF4XP1F2G0TKOJ32M

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # crear la URL de solicitud de API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # solicitud GET
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # regresa solo información relevante de cada sitio cercano
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_demo2['Neighborhood_x'],
                                   latitudes=df_demo2['Latitude'],
                                   longitudes=df_demo2['Longitude']
                                  )
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth
# Danforth East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# ...

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (2796, 7)
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Agincourt North              43.808038              -79.266439
# 1  Agincourt North              43.808038              -79.266439
# 2  Agincourt North              43.808038              -79.266439
# 3  Agincourt North              43.808038              -79.266439
# 4  Agincourt North              43.808038              -79.266439
#
#                                       Venue  Venue Latitude  Venue Longitude  \
# 0                                 Menchie's       43.808338       -79.268288
# 1  Saravanaa Bhavan South Indian Restaurant       43.810117       -79.269275
# 2                          Congee Town 太皇名粥       43.809035       -79.267634
# 3                             Booster Juice       43.809915       -79.269382
# 4                        Shoppers Drug Mart       43.808894       -79.269854
#
#        Venue Category
# 0  Frozen Yogurt Shop
# 1   Indian Restaurant
# 2  Chinese Restaurant
# ...

# %%
toronto_venues.to_csv('toronto_venues.csv')

# %%
toronto_venues=pd.read_csv('toronto_venues.csv',index_col=0)
#toronto_venues.head()

# %%
venues_cat=toronto_venues['Venue Category'].tolist()

# %%
len(venues_cat), type(venues_cat)
# Out:
# (2796, list)

# %%
search_list = [ 'Argentinian', 'Brazilian', 'Uruguayan', 'Chilean', 'Paraguayan', 
               'Parrilla', 'Parrillada', 'Asado', 'Asador']
len(search_list), type(search_list)
# Out:
# (9, list)

# %%
for i in range(len(venues_cat)):
    for j in range(len(search_list)):
        if search_list[j] in venues_cat[i]:
            print(search_list[j], search_list.index(search_list[j]), venues_cat[i], venues_cat.index(venues_cat[i]) )
        else:
            pass
# Out:
# Brazilian 1 Brazilian Restaurant 471
# Argentinian 0 Argentinian Restaurant 2786

# %%
toronto_venues2=toronto_venues[(toronto_venues['Venue Category'] =='Argentinian Restaurant')
               | (toronto_venues['Venue Category'] =='Brazilian Restaurant')]
toronto_venues2
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 471   Corso Italia-Davenport              43.677954              -79.443083
# 2786      Yorkdale-Glen Park              43.703434              -79.452918
#
#                      Venue  Venue Latitude  Venue Longitude  \
# 471           Rio 40 Graus       43.677329       -79.446298
# 2786  Sky Ranch Restaurant       43.700730       -79.451684
#
#               Venue Category
# 471     Brazilian Restaurant
# 2786  Argentinian Restaurant

# %%
address = 'Toronto, TOR'
geolocator = Nominatim(user_agent="Tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.7370584, -79.2442535.

# %%
# crear mapa
map_clusters2 = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster, radio in zip(df_demo2['Latitude'], df_demo2['Longitude'],
                                         df_demo2['Neighborhood_x'], df_demo2['Cluster Labels'], df_demo2['Total Normalizado']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10*radio,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters2)

for venlat, venlon, vencat, venue, nei in zip(toronto_venues2['Venue Latitude'], toronto_venues2['Venue Longitude'],
                                         toronto_venues2['Venue Category'], toronto_venues2['Venue'], 
                                              toronto_venues2['Neighborhood']):
    label = folium.Popup(venue + ' ' + vencat , parse_html=True)
    folium.Marker([venlat, venlon],popup=label).add_to(map_clusters2)

# %%
map_clusters2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
df_demo2[df_demo2['Cluster Labels']==0].describe()
# Out:
#        Cluster Labels      Hood #  Total income: Average amount ($)  \
# count           113.0  113.000000                        113.000000
# mean              0.0   70.238938                      41146.238938
# std               0.0   42.461805                       9981.387720
# min               0.0    1.000000                      25989.000000
# 25%               0.0   32.000000                      32724.000000
# 50%               0.0   69.000000                      38527.000000
# 75%               0.0  111.000000                      48511.000000
# max               0.0  140.000000                      65274.000000
#
#        Total migrantes sudamericanos  Total Normalizado  Total Income Norm  \
# count                     113.000000         113.000000         113.000000
# mean                      206.327434           0.209469           0.133587
# std                       189.888381           0.192780           0.032406
# ...

# %%
df_demo2[df_demo2['Cluster Labels']==1].describe()
# Out:
#        Cluster Labels      Hood #  Total income: Average amount ($)  \
# count            22.0   22.000000                         22.000000
# mean              1.0   67.909091                      92299.090909
# std               0.0   32.586747                      22090.128021
# min               1.0    9.000000                      67757.000000
# 25%               1.0   40.500000                      72008.750000
# 50%               1.0   72.500000                      87335.000000
# 75%               1.0   96.500000                     109185.250000
# max               1.0  114.000000                     144642.000000
#
#        Total migrantes sudamericanos  Total Normalizado  Total Income Norm  \
# count                      22.000000          22.000000          22.000000
# mean                      165.227273           0.167743           0.299663
# std                       159.988670           0.162425           0.071719
# ...

# %%
df_demo2[df_demo2['Cluster Labels']==2].describe()
# Out:
#        Cluster Labels     Hood #  Total income: Average amount ($)  \
# count             5.0    5.00000                          5.000000
# mean              2.0   87.80000                     210936.800000
# std               0.0   26.30019                      57708.657056
# min               2.0   41.00000                     165047.000000
# 25%               2.0   96.00000                     169203.000000
# 50%               2.0   98.00000                     204521.000000
# 75%               2.0  101.00000                     207903.000000
# max               2.0  103.00000                     308010.000000
#
#        Total migrantes sudamericanos  Total Normalizado  Total Income Norm  \
# count                       5.000000           5.000000           5.000000
# mean                      113.000000           0.114721           0.684838
# std                        63.796552           0.064768           0.187360
# ...
